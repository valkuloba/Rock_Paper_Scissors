# %%
# Import the random module
import random

# Generate a random number between 1 and 100
secret_number = random.randint(1, 100)

# Set the maximum number of attempts
max_attempts = 7

# Start the guessing loop
for attempt in range(1, max_attempts + 1):
    print(f"Attempt {attempt} of {max_attempts}")

    # Ask the user to guess the number
    guess = int(input("Guess a number between 1 and 100: "))

    # Check the user's guess
    if guess < secret_number:
        print("Too low! Try a higher number.\n")
    elif guess > secret_number:
        print("Too high! Try a lower number.\n")
    else:
        print("🎉 Correct! You guessed the number!")
        break
else:
    # Runs if the loop finishes without a correct guess
    print(f"Sorry! The correct number was {secret_number}.")
# Out:
# Running cells with 'Python 3.14.0' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/HomePC/AppData/Local/Programs/Python/Python314/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
import random
secret_number = random.randint(1, 100)
print (secret_number)

attempts = 3
count = 0

print("I have generated a random number between 1 and 100.")
print(f"You have [attempts] attempts to guess it.")

while count < attempts:
    guess_num = int(input("Enter your guess"))

    if guess_num < secret_number:
    print("Too low")
    elif guess_num > secret_number:
    print("Too high")
    elif guess_num > secret_number:
    print("Too high")
else:
print("Congratulations! You have guessed the secret_number")
break

if count == attempts and guess_num != secret number:
print (f"Sorry! The correct number was 53")
# Out:
#   Cell In[4], line 15
#     print("Too low")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 14

# %%
def greet():
    print("Hello Val")

greet()
# Out:
# Hello Val

# %%
def greet(name):   # name is a parameter
    print("Hello", name)

greet("Val")      # "Val" is an argument
# Out:
# Hello Val

# %%
def add(a, b):
    print(a + b)

add(3, 5)
# Out:
# 8

# %%
print(add(b=2, a=10))
# Out:
# 12
# None

# %%
def greet(name = "Guest"):
    print(f"Hello, {name}!")
greet()
greet("Val")
# Out:
# Hello, Guest!
# Hello, Val!

# %%
def print numbers(*args):
    for num

# %%
def print_info(**kwargs):
    for key, value in kwargs.items():
        print(f"{key}: {value}")
print_info(name = "Val" age=20, country="Kenya")
# Out:
#   Cell In[14], line 4
#     print_info(name = "Val" age=20, country="Kenya")
#                       ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
